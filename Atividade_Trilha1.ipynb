# %% [markdown]
# <a href="https://colab.research.google.com/github/rogeriovianacelular/Ling-de-Prog-para-Ciencia-de-Dados/blob/main/Atividade_Trilha1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Escolha do texto:** Escolhi os cinco primeiros capitulos do evangelho de Mateus apenas por curiosidade, devido a sua extensão de palavras.

# %% [markdown]
# ## Obtenção dos Dados

# %%
import urllib.request  

texto = []

for line in urllib.request.urlopen('https://raw.githubusercontent.com/rogeriovianacelular/paradigmasprogramacao/main/Evangelho_Mateus_Cap%201-5.txt'): 
    texto.append(line.decode('utf-8'))

# f = open('/kate_beckinsale.txt','r')    # para arquivos locais
# for line in f:
#    texto.append(line)

for i in range(len(texto)):
    texto[i] = texto[i].lower() # para unicidade
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','') # elimina ' e "

# %% [markdown]
# # Construção do Dicionário

# %%
mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra
#  print(words)

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'novo': 1, 'testamento': 1, 'mateus': 6, '1': 6, 'livro': 1, 'da': 23, 'genealogia': 1, 'de': 73, 'jesus': 15, 'cristo': 5, 'filho': 10, 'davi': 6, 'abraão': 4, '2': 6, 'a': 115, 'nasceu': 37, 'isaque;': 1, 'isaque': 1, 'jacó;': 2, 'jacó': 2, 'nasceram': 3, 'judá': 3, 'e': 124, 'seus': 11, 'irmãos;': 1, '3': 6, 'tamar': 1, 'farés': 2, 'zará;': 1, 'esrom;': 1, 'esrom': 1, 'arão;': 1, '4': 6, 'arão': 1, 'aminadabe;': 1, 'aminadabe': 1, 'nasom;': 1, 'nasom': 1, 'salmom;': 1, '5': 6, 'salmom': 1, 'raabe': 1, 'booz;': 1, 'booz': 1, 'rute': 1, 'obede;': 1, 'obede': 1, 'jessé;': 1, '6': 5, 'jessé': 1, 'o': 86, 'rei': 5, 'salomão': 2, 'que': 103, 'fora': 9, 'mulher': 5, 'urias;': 1, '7': 5, 'roboão;': 1, 'roboão': 1, 'abias;': 1, 'abias': 1, 'asafe;': 1, '8': 5, 'asafe': 1, 'josafá;': 1, 'josafá': 1, 'jorão;': 1, 'jorão': 1, 'ozias;': 1, '9': 5, 'ozias': 1, 'joatão;': 1, 'joatão': 1, 'acaz;': 1, 'acaz': 1, 'ezequias;': 1, '10': 5, 'ezequias': 1, 'manassés;': 1, 'manassés': 1, 'amom;': 1, 'a
# ...

# %% [markdown]
# # Exibição dos Resultados

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências
# df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()

# %% [markdown]
# **Conclusão:** O primeiro texto que escolhi foi a bíblia sagrada completa, pois queria realmente testar a quantidade palavras e o processamento. Fiquei impressionado com a rapidez da execução do código, senão me engano, foi em menos de 1 minuto. Porém para esse exercício, a quantidade de palavras ficou muito grande para o gráfico.
# Por fim, utilizei apenas os 5 primeiros capitulos do evangelho de Mateus e gostei do resultado.
